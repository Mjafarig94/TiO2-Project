# %%
MaxGlobal=0
MaxGlobal_Score=0
MaxGlobal_Score_train=0

scores = {'CV': [], 'R2': [],'R2_train': []}

for j in range(5000,5051):
    from sklearn.model_selection import cross_val_score
    from sklearn.ensemble import GradientBoostingRegressor
    import numpy as np
    import pandas as pd
    import pickle
    from sklearn import metrics
    from sklearn import preprocessing
    from sklearn.model_selection import train_test_split
    from sklearn.model_selection import cross_val_predict
    import matplotlib.pyplot as plt
    #from neupy.algorithms import RBFKMeans
    #from neupy.algorithms import GRNN
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.metrics import r2_score
    from sklearn.svm import SVR
    from sklearn.neural_network import MLPRegressor
    from sklearn.neural_network import MLPClassifier
    from sklearn.linear_model import LogisticRegression
    from sklearn.tree import DecisionTreeRegressor
    from sklearn.ensemble import AdaBoostRegressor
    from sklearn import linear_model
    import seaborn as sn
    import joblib
    from math import sqrt
    from sklearn.metrics import mean_absolute_error as mae
    import pandas as pd
    from sklearn.linear_model import LogisticRegression
    from sklearn.model_selection import GridSearchCV
    import warnings
    warnings.filterwarnings('ignore', category=FutureWarning)
    warnings.filterwarnings('ignore', category=DeprecationWarning)





    file_name = 'CA'
    dataset = pd.read_csv(file_name + '.csv', header=0)
    Test=dataset.loc[dataset['phi'] == 0.5]
    data= dataset[dataset.phi != 0.5]

    x1 = data.phi
    x2= data.ca
    X = np.column_stack((x1,x2))
    Y= np.asarray(data.uv).reshape(-1, 1)
    X_train, X_test,Y_train, Y_test = train_test_split(X, Y, test_size = 0.2,random_state=j,stratify=X[:,0])


    xscaler = preprocessing.StandardScaler()
    X_train_standard=xscaler.fit_transform(X_train)
    X_test_standard=xscaler.transform(X_test)

    yscaler = preprocessing.StandardScaler()
    Y_train_standard =yscaler.fit_transform(Y_train)
    Y_test_standard =yscaler.transform(Y_test)

    Y_train_standard=Y_train_standard.ravel()
    Y_test_standard =Y_test_standard.ravel() 

    X1 = Test.phi
    X2= Test.ca
    XX = np.column_stack((X1,X2))
    YY= np.asarray(Test.uv).reshape(-1, 1)
    X_scaled=xscaler.transform(XX)
    Y_scaled=yscaler.transform(YY)
    Y_scaled=Y_scaled.ravel()




    def print_results_max(results):
        print('BEST PARAMS: {}\n'.format(results.best_params_))
        MAxMean=0
        means = results.cv_results_['mean_test_score']
        stds = results.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, results.cv_results_['params']):
            if mean > MAxMean :
                MAxMean = mean
                print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))
        return MAxMean



 # 'kernel' : ['linear', 'rbf','poly'],
    SVM =SVR()
    parameters = {
            'kernel' : ['rbf', 'poly'],
            'degree' : list(np.arange(1,20,1)),
            'epsilon': [0.1,0],
             'C': list(np.arange(.01,1,0.1))
    }

    cv = GridSearchCV(SVM, parameters, cv=5)
    cv.fit(X_train_standard, Y_train_standard)



    MAxMean=print_results_max(cv)
    Score= cv.best_estimator_.score(X_test_standard, Y_test_standard).round(4)
    Score_train= cv.best_estimator_.score(X_train_standard, Y_train_standard).round(4)

    scores['CV'].append(MAxMean) 
    scores['R2'].append(Score)
    scores['R2_train'].append(Score_train)

    if MAxMean > MaxGlobal and Score>MaxGlobal_Score and Score_train>MaxGlobal_Score_train:
        MaxGlobal=MAxMean
        MaxGlobal_Score= Score
        MaxGlobal_Score_train = Score_train
        BestFit=cv.best_estimator_
        SVM_X_train_standard=X_train_standard
        SVM_Y_train_standard=Y_train_standard
        SVM_X_test_standard=X_test_standard
        SVM_Y_test_standard=Y_test_standard
        
        SVMrbf_Y_train_standard_realscale=yscaler.inverse_transform(Y_train_standard.reshape(-1, 1))
        SVMrbf_Y_test_standard_realscale=yscaler.inverse_transform(Y_test_standard.reshape(-1, 1))
        ypredtrain=BestFit.predict(X_train_standard)
        ypredtest=BestFit.predict(X_test_standard)
        SVMrbf_pred_Y_train_standard_realscale=yscaler.inverse_transform(ypredtrain.reshape(-1, 1))
        SVMrbf_pred_Y_test_standard_realscale=yscaler.inverse_transform(ypredtest.reshape(-1, 1))
        np.save('SVMrbf_Y_train_standard_realscale',SVMrbf_Y_train_standard_realscale)
        np.save('SVMrbf_Y_test_standard_realscale',SVMrbf_Y_test_standard_realscale)
        np.save('SVMrbf_pred_Y_train_standard_realscale',SVMrbf_pred_Y_train_standard_realscale)
        np.save('SVMrbf_pred_Y_test_standard_realscale',SVMrbf_pred_Y_test_standard_realscale)
        
        Number_Of_Estimators = j
        np.save('SVMrbf_X_train_standard',SVM_X_train_standard)
        np.save('SVMrbf_Y_train_standard',SVM_Y_train_standard)
        np.save('SVMrbf_X_test_standard',SVM_X_test_standard)
        np.save('SVMrbf_Y_test_standard',SVM_Y_test_standard)
        Xscaler=xscaler
        Yscaler=yscaler
        ypredTest=BestFit.predict(X_scaled)
        Testscore=r2_score(Y_scaled,ypredTest)
        joblib.dump(BestFit, 'SVM_modelrbf.pkl')
        
    
S=pd.DataFrame(scores) 
axis = S.boxplot()
axis.set_ylim([0,1]);
np.save('SVMrbf_CV',S.CV)
np.save('SVMrbfr_R2',S.R2)
np.save('SVMrbf_R2_train',S.R2_train)
print("mean CV {0}".format(S.CV.mean()))
print("mean R2 {0}".format(S.R2.mean()))
print("mean R2_train {0}".format(S.R2_train.mean()))
print("Test Score {0}".format(Testscore))


print("test r2 = {}".format(r2_score(SVMrbf_Y_test_standard_realscale,SVMrbf_pred_Y_test_standard_realscale)))
print("test RMSE: {0} and MAE: {1}".format(sqrt(np.mean((SVMrbf_Y_test_standard_realscale - SVMrbf_pred_Y_test_standard_realscale)**2)),mae(SVMrbf_Y_test_standard_realscale, SVMrbf_pred_Y_test_standard_realscale).round(3)))

print("train r2 = {}".format(r2_score(SVMrbf_Y_train_standard_realscale,SVMrbf_pred_Y_train_standard_realscale)))
print("train RMSE: {0} and MAE: {1}".format(sqrt(np.mean((SVMrbf_Y_train_standard_realscale - SVMrbf_pred_Y_train_standard_realscale)**2)),mae(SVMrbf_Y_train_standard_realscale, SVMrbf_pred_Y_train_standard_realscale).round(3)))
# Out:
# BEST PARAMS: {'C': 0.91, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
#
# 0
for {'C': 0.6100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.875 (+/-0.116) for {'C': 0.7100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.878 (+/-0.123) for {'C': 0.7100000000000001, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.897 (+/-0.101) for {'C': 0.81, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.909 (+/-0.096) for {'C': 0.81, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.913 (+/-0.086) for {'C': 0.91, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.928 (+/-0.075) for {'C': 0.91, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.91, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
#
# 0.429 (+/-0.392) for {'C': 0.11, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.454 (+/-0.388) for {'C': 0.11, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.594 (+/-0.279) for {'C': 0.21000000000000002, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.709 (+/-0.192) for {'C': 0.31000000000000005, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.764 (+/-0.155) for {'C': 0.41000000000000003, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.766 (+/-0.193) for {'C': 0.41000000000000003, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.819 (+/-0.133) for {'C': 0.51, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.823 (+/-0.14) for {'C': 0.51, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.859 (+/-0.103) for {'C': 0.6100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.883 (+/-0.086) for {'C': 0.7100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.898 (+/-0.078) for {'C': 0.81, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.901 (+/-0.085) for {'C': 0.81, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.909 (+/-0.074) for {'C': 0.91, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.916 (+/-0.075) for {'C': 0.91, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.91, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
#
# 0.453 (+/-0.261) for {'C': 0.11, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.64 (+/-0.248) for {'C': 0.21000000000000002, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.657 (+/-0.271) for {'C': 0.21000000000000002, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.747 (+/-0.235) for {'C': 0.31000000000000005, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.81 (+/-0.191) for {'C': 0.41000000000000003, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.84 (+/-0.173) for {'C': 0.51, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.861 (+/-0.156) for {'C': 0.6100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.866 (+/-0.135) for {'C': 0.6100000000000001, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.88 (+/-0.134) for {'C': 0.7100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.887 (+/-0.118) for {'C': 0.7100000000000001, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.896 (+/-0.111) for {'C': 0.81, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.9 (+/-0.106) for {'C': 0.81, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.909 (+/-0.089) for {'C': 0.91, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.909 (+/-0.101) for {'C': 0.91, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# BEST PARAMS: {'C': 0.91, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
#
# 0.46 (+/-0.371) for {'C': 0.11, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.598 (+/-0.219) for {'C': 0.21000000000000002, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.664 (+/-0.178) for {'C': 0.31000000000000005, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.716 (+/-0.209) for {'C': 0.41000000000000003, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.781 (+/-0.186) for {'C': 0.51, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.817 (+/-0.173) for {'C': 0.6100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.837 (+/-0.167) for {'C': 0.7100000000000001, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.861 (+/-0.162) for {'C': 0.81, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.867 (+/-0.155) for {'C': 0.81, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# 0.878 (+/-0.168) for {'C': 0.91, 'degree': 1, 'epsilon': 0.1, 'kernel': 'rbf'}
# 0.885 (+/-0.152) for {'C': 0.91, 'degree': 1, 'epsilon': 0, 'kernel': 'rbf'}
# mean CV 0.8960616629356466
# mean R2 0.9391725490196082
# mean R2_train 0.9621450980392156
# Test Score -0.03096515797149091
# test r2 = 0.9724540608094256
# test RMSE: 2.075719967094124 and MAE: 1.591
# train r2 = 0.9673935055282452
# train RMSE: 2.507972047658868 and MAE: 1.428

# %%
Number_Of_Estimators #random state in train-test-split function
# Out:
# 5009

# %%
MaxGlobal
# Out:
# 0.9381866831288346

# %%
MaxGlobal_Score
# Out:
# 0.9725

# %%
BestFit
# Out:
# SVR(C=0.91, degree=1, epsilon=0)

# %%
file_name = 'CA0.5'
data = pd.read_csv(file_name + '.csv', header=0)

x1 = data.phi
x2= data.ca
X = np.column_stack((x1,x2))
Y= np.asarray(data.uv).reshape(-1, 1)
X_scaled=Xscaler.transform(X)
Y_scaled=Yscaler.transform(Y)
Y_scaled=Y_scaled.ravel()
ypred=BestFit.predict(X_scaled)
actually_SVMrbf=Yscaler.inverse_transform(ypred.reshape(-1,1))

from sklearn.metrics import r2_score
from math import sqrt
from sklearn.metrics import mean_absolute_error as mae
np.save('actually_SVMrbf',actually_SVMrbf)
plt.scatter(x2,actually_SVMrbf,color="none",edgecolor="red")
plt.scatter(x2,Y,marker='+')


print("r2 = {}".format(r2_score(Y,actually_SVMrbf)))
print("RMSE: {0} and MAE: {1}".format(sqrt(np.mean((Y - actually_SVMrbf)**2)),mae(Y, actually_SVMrbf).round(3)))
# Out:
# r2 = -0.03096515797149113
# RMSE: 4.0930653326128 and MAE: 3.377
